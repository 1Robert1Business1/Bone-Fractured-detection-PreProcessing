# %% [markdown]
# **Normalization**

# %% [raw]
# Normalize the pixel values of images to a common scale (e.g., [0, 1] or [-1, 1]). This helps in speeding up training and improving convergence.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import random
import os

# Directory containing the images
directory = '/home/elt/rw372/notebook/COMP8260 - A.I Systems/Project/Dataset/test/images'

# List all the image files in the directory
image_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.jpg')]

# Choose a random image file
random_image_path = random.choice(image_files)

# Load the random image
random_image = Image.open(random_image_path)

# Convert the image to a numpy array
image_array = np.array(random_image)

# Normalize the image array
normalized_image_array = (image_array - np.min(image_array)) / (np.max(image_array) - np.min(image_array))

# Plot the original and normalized images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_array)
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(normalized_image_array)
plt.title("Normalized Image")
plt.axis('off')

plt.show()

# %% [markdown]
# **Normalizsed Dataset**

# %%
import os
from PIL import Image
import numpy as np
import random
import matplotlib.pyplot as plt

# Define the directory containing the original dataset
original_dataset_dir = "/home/elt/rw372/notebook/COMP8260 - A.I Systems/Project/Dataset"

# Define the directory to save the normalized and resized images
output_dir = "/home/elt/rw372/notebook/COMP8260 - A.I Systems/Project/Normalized_Resized_Dataset"

# Define the target size for resizing
target_size = (256, 256)

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Function to normalize and resize an image
def normalize_and_resize_image(image_path):
    # Load the image
    image = Image.open(image_path)
    
    # Normalize the pixel values
    image_array = np.array(image)
    normalized_image_array = (image_array - np.min(image_array)) / (np.max(image_array) - np.min(image_array))
    
    # Resize the image
    resized_image = image.resize(target_size)
    
    return resized_image

print("Normalization and resizing completed.")
# Out:
# Normalization and resizing completed.

# %%
# Function to plot original and normalized images
def plot_images(original_image, normalized_image):
    plt.figure(figsize=(10, 5))
    
    # Plot the original image
    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title("Original Image")
    plt.axis('off')
    
    # Plot the normalized image
    plt.subplot(1, 2, 2)
    plt.imshow(normalized_image)
    plt.title("Normalized Image")
    plt.axis('off')
    
    plt.show()

# Choose a random image from the dataset
image_files = [os.path.join(original_dataset_dir, 'train', 'images', file) for file in os.listdir(os.path.join(original_dataset_dir, 'train', 'images')) if file.endswith('.jpg')]
random_image_path = random.choice(image_files)

# Normalize and resize the chosen image
original_image = Image.open(random_image_path)
normalized_image = normalize_and_resize_image(random_image_path)

# Plot the original and normalized images
plot_images(original_image, normalized_image)

# %% [raw]
# Normalization helps in training machine learning models by ensuring that features (pixel values in this case) are on a similar scale, which can improve convergence during training and prevent issues like exploding gradients.
#
# Applying normalization to medical images can have several benefits:
#
# Consistency in Scale: Medical images often have varying intensity ranges due to differences in imaging devices or protocols. Normalization helps to standardize the intensity values across different images, making them more consistent and easier to analyze.
#
# Improved Model Performance: Normalization can improve the performance of machine learning models trained on medical images. By scaling the pixel values to a consistent range, normalization can prevent the dominance of certain features and facilitate better convergence during model training.
#
# Enhanced Feature Detection: Normalization can enhance the detection of subtle features in medical images by improving the contrast between different tissues or structures. This can be particularly important in tasks such as tumor detection, where accurate delineation of boundaries is crucial.
#
# Reduced Computational Complexity: Normalization can help reduce the computational complexity of image processing tasks by ensuring that pixel values are within a bounded range. This can lead to more stable and efficient algorithms for tasks such as image segmentation or registration.
